# %%
import pandas as pd
import glob
import os

path = './' 

excel_files = glob.glob(os.path.join(path, '*.xlsx'))

df_list = []

# Loop through the list of file names, read each file, and append to the list
for file in excel_files:
    # Read the excel file
    print(file)
    df = pd.read_excel(file)
    # Optional: Add a column to identify the source file
    df['source_file'] = os.path.basename(file) 
    df_list.append(df)

# Concatenate all DataFrames in the list into a single DataFrame
master_df = pd.concat(df_list, ignore_index=True)
# Out:
# ./2018.xlsx
# ./2024.xlsx
# ./2020.xlsx
# ./2016.xlsx
# /home/lex/learn/bfu/course_work/atp_tml_database/.venv/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# ./2022.xlsx
# ./2017.xlsx
# ./2015.xlsx
# /home/lex/learn/bfu/course_work/atp_tml_database/.venv/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# ./2025.xlsx
# ./2021.xlsx
# ./2019.xlsx
# ./2023 .xlsx
# ./2026.xlsx

# %%
master_df.Date.min()
# Out:
# Timestamp('2015-01-05 00:00:00')

# %%
odds_df.Date.max()
# Out:
# Timestamp('2025-11-16 00:00:00')
